# %% [markdown]
# * Use the wikiproject tree generated from https://github.com/wiki-ai/drafttopic/tree/master/drafttopic/utilities

# %%
import json, networkx as nx
import pickle

# %%
with open('wp_2017-11-05.json') as f: tree = json.load(f)

# %%
def getLinks(dictCat):
    return dictCat.get('topics',{})

def normalizeName(name): #normalize names to match with SQL output, see example here: https://quarry.wmflabs.org/query/23214
    if name.startswith("Wikipedia:"):
        name =name[10:]
    if not name.startswith("WikiProject"):
        name = "WikiProject_"+name
    name = name+"_articles"
    name = name.replace(' ','_')
    return name

# %%
root= {'topics':tree,'name':'root'}

visited = []
G = nx.Graph()
stack = [root]
while stack:
    #print(stack)
    current = stack.pop()
    childs = getLinks(current)
    #print(childs)
    visited.append(current)
    #print(current)
    for topic,topicDict in childs.items():
            if topicDict['name'] != current['name']: #avoid selfloops
                G.add_edge(topicDict['name'],current['name'])
            if c not in visited+stack:
                stack.append(topicDict)

# %%
nx.algorithms.is_tree(G)
# Out:
# False

# %%
len(nx.cycle_basis(G))
# Out:
# 120

# %%
nx.cycle_basis(G)
# Out:
# [['East Midlands',
#   'Wikipedia:WikiProject Lincolnshire',
#   'Yorkshire and the Humber',
#   'England'],
#  ['Cambridge', 'Wikipedia:WikiProject East Anglia', 'East of England'],
#  ['Nigeria', 'Western Africa', 'Gambia', 'Wikipedia:WikiProject Commonwealth'],
#  ['Sierra Leone',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Ghana', 'Western Africa', 'Gambia', 'Wikipedia:WikiProject Commonwealth'],
#  ['Countries',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['History and society',
#   'General topics',
#   'Wikipedia:WikiProject Former countries',
#   'History'],
#  ['Wikipedia:WikiProject History of Science',
#   'History of science',
#   'Science',
#   'Wikipedia:WikiProject Forestry',
#   'General topics',
#   'Wikipedia:WikiProject Former countries',
#   'History'],
#  ['Wikipedia:WikiProject Psychology',
#   'Medicine',
#   'Science, technology, and engineering',
#   'Science',
#   'Wikipedia:WikiProject Forestry',
#   'General topics'],
#  ['History and society',
#   'Politics and government',
#   'International',
#   'Wikipedia:WikiProject Sanitation',
#   'Medicine',
#   'Science, technology, and engineering',
#   'Science',
#   'Wikipedia:WikiProject Forestry',
#   'General topics'],
#  ['Biology',
#   'Tree of Life',
#   'Plants',
#   'Wikipedia:WikiProject Cannabis',
#   'Politics and government',
#   'International',
#   'Wikipedia:WikiProject Sanitation',
#   'Medicine',
#   'Science, technology, and engineering'],
#  ['Marine life',
#   'Wikipedia:WikiProject Gastropods',
#   'Animals',
#   'Tree of Life'],
#  ['Marine life', 'Wikipedia:WikiProject Bivalves', 'Animals', 'Tree of Life'],
#  ['Wikipedia:WikiProject Animal rights',
#   'Law',
#   'Politics and government',
#   'International',
#   'Wikipedia:WikiProject Sanitation',
#   'Medicine',
#   'Science, technology, and engineering',
#   'Science',
#   'Wikipedia:WikiProject Forestry',
#   'General topics'],
#  ['Wikipedia:WikiProject United States History',
#   'United States',
#   'Wikipedia:WikiProject FBI',
#   'Law enforcement',
#   'Law',
#   'Politics and government',
#   'International',
#   'Wikipedia:WikiProject Sanitation',
#   'Medicine',
#   'Science, technology, and engineering',
#   'Science',
#   'Wikipedia:WikiProject Forestry',
#   'General topics',
#   'Wikipedia:WikiProject Former countries',
#   'History'],
#  ['History and society',
#   'root',
#   'Culture and the arts',
#   'Sports',
#   'Wikipedia:WikiProject Caves',
#   'Landforms',
#   'Mountains',
#   'Wikipedia:WikiProject New Hampshire Mountains',
#   'Michigan–New York',
#   'United States',
#   'Wikipedia:WikiProject FBI',
#   'Law enforcement',
#   'Law',
#   'Politics and government'],
#  ['Science, technology and engineering',
#   'root',
#   'Culture and the arts',
#   'Sports',
#   'Wikipedia:WikiProject Caves',
#   'Landforms',
#   'Mountains',
#   'Wikipedia:WikiProject New Hampshire Mountains',
#   'Michigan–New York',
#   'United States',
#   'Wikipedia:WikiProject FBI',
#   'Law enforcement',
#   'Law',
#   'Politics and government',
#   'International',
#   'Wikipedia:WikiProject Sanitation',
#   'Medicine',
#   'Science, technology, and engineering'],
#  ['Geography',
#   'Geographical',
#   'root',
#   'Culture and the arts',
#   'Sports',
#   'Wikipedia:WikiProject Caves',
#   'Landforms'],
#  ['Maintenance',
#   'Wikipedia:WikiProject Council',
#   'WikiProjects',
#   'Wikipedia assistance and tasks'],
#  ['Maintenance',
#   'Wikipedia:Help Project',
#   'Contents systems',
#   'Wikipedia assistance and tasks'],
#  ['Maintenance',
#   'Wikipedia:WikiProject Portals',
#   'Contents systems',
#   'Wikipedia assistance and tasks'],
#  ['Wikipedia:WikiProject Alternative Views',
#   'Maintenance',
#   'Wikipedia assistance and tasks',
#   'root',
#   'Culture and the arts',
#   'Sports',
#   'Wikipedia:WikiProject Caves',
#   'Landforms',
#   'Mountains',
#   'Wikipedia:WikiProject New Hampshire Mountains',
#   'Michigan–New York',
#   'United States',
#   'Wikipedia:WikiProject FBI',
#   'Law enforcement',
#   'Law',
#   'Politics and government',
#   'International',
#   'Wikipedia:WikiProject Sanitation',
#   'Medicine',
#   'Science, technology, and engineering',
#   'Science',
#   'Wikipedia:WikiProject Forestry',
#   'General topics'],
#  ['Wikipedia:WikiProject Leaders by year',
#   'Biography',
#   'Wikipedia:WikiProject Persondata',
#   'Maintenance',
#   'Wikipedia assistance and tasks',
#   'root',
#   'Culture and the arts',
#   'Sports',
#   'Wikipedia:WikiProject Caves',
#   'Landforms',
#   'Mountains',
#   'Wikipedia:WikiProject New Hampshire Mountains',
#   'Michigan–New York',
#   'United States',
#   'Wikipedia:WikiProject FBI',
#   'Law enforcement',
#   'Law',
#   'Politics and government',
#   'International',
#   'Wikipedia:WikiProject Sanitation',
#   'Medicine',
#   'Science, technology, and engineering',
#   'Science',
#   'Wikipedia:WikiProject Forestry',
#   'General topics'],
#  ['Language and literature',
#   'Biography',
#   'Wikipedia:WikiProject Persondata',
#   'Maintenance',
#   'Wikipedia assistance and tasks',
#   'root',
#   'Culture and the arts'],
#  ['Wikipedia:WikiProject Community',
#   'Sociology',
#   'Wikipedia:WikiProject Genealogy',
#   'Biography',
#   'Wikipedia:WikiProject Persondata',
#   'Maintenance'],
#  ['History and society',
#   'Sociology',
#   'Wikipedia:WikiProject Genealogy',
#   'Biography',
#   'Wikipedia:WikiProject Persondata',
#   'Maintenance',
#   'Wikipedia assistance and tasks',
#   'root'],
#  ['Wikipedia:WikiProject Pedophilia Article Watch',
#   'Sociology',
#   'Wikipedia:WikiProject Genealogy',
#   'Biography',
#   'Wikipedia:WikiProject Persondata',
#   'Maintenance'],
#  ['Wikipedia:WikiProject Organizations', 'Social organizations', 'Sociology'],
#  ['Biology',
#   'Sexology and Sexuality',
#   'Wikipedia:WikiProject LGBT studies',
#   'Sociology',
#   'Wikipedia:WikiProject Genealogy',
#   'Biography',
#   'Wikipedia:WikiProject Persondata',
#   'Maintenance',
#   'Wikipedia assistance and tasks',
#   'root',
#   'Culture and the arts',
#   'Sports',
#   'Wikipedia:WikiProject Caves',
#   'Landforms',
#   'Mountains',
#   'Wikipedia:WikiProject New Hampshire Mountains',
#   'Michigan–New York',
#   'United States',
#   'Wikipedia:WikiProject FBI',
#   'Law enforcement',
#   'Law',
#   'Politics and government',
#   'International',
#   'Wikipedia:WikiProject Sanitation',
#   'Medicine',
#   'Science, technology, and engineering'],
#  ['Wikipedia:WikiProject Gender Studies',
#   'Sexology and Sexuality',
#   'Wikipedia:WikiProject LGBT studies',
#   'Sociology'],
#  ['Language and literature', 'Literature', 'Biography'],
#  ['Wikipedia:WikiProject Wikipedia',
#   'Literature',
#   'Biography',
#   'Wikipedia:WikiProject Persondata',
#   'Maintenance'],
#  ['Entertainment',
#   'Films',
#   'Wikipedia:WikiProject Star Wars',
#   'Media franchises',
#   'Literature',
#   'Biography',
#   'Wikipedia:WikiProject Persondata',
#   'Maintenance',
#   'Wikipedia assistance and tasks',
#   'root',
#   'Culture and the arts'],
#  ['Broadcasting',
#   'Television',
#   'British TV shows and channels',
#   'Wikipedia:WikiProject Thomas',
#   'Media franchises',
#   'Literature',
#   'Biography',
#   'Wikipedia:WikiProject Persondata',
#   'Maintenance',
#   'Wikipedia assistance and tasks',
#   'root',
#   'Culture and the arts'],
#  ['Wikipedia:WikiProject Academic Journals', 'Journalism', 'Literature'],
#  ['Linguistics', 'Linguistics and writing systems', 'Literature', 'Biography'],
#  ['Language and literature', 'Linguistics and writing systems', 'Literature'],
#  ['Technology',
#   'Computing',
#   'Wikipedia:WikiProject Blogging',
#   'Literature',
#   'Biography',
#   'Wikipedia:WikiProject Persondata',
#   'Maintenance',
#   'Wikipedia assistance and tasks',
#   'root',
#   'Culture and the arts',
#   'Sports',
#   'Wikipedia:WikiProject Caves',
#   'Landforms',
#   'Mountains',
#   'Wikipedia:WikiProject New Hampshire Mountains',
#   'Michigan–New York',
#   'United States',
#   'Wikipedia:WikiProject FBI',
#   'Law enforcement',
#   'Law',
#   'Politics and government',
#   'International',
#   'Wikipedia:WikiProject Sanitation',
#   'Medicine',
#   'Science, technology, and engineering'],
#  ['Language and literature', 'Linguistics', 'Biography'],
#  ['Performing arts',
#   'Music',
#   'Popular musicians',
#   'Wikipedia:WikiProject Musicians',
#   'Biography',
#   'Wikipedia:WikiProject Persondata',
#   'Maintenance',
#   'Wikipedia assistance and tasks',
#   'root',
#   'Culture and the arts'],
#  ['Performing arts',
#   'Opera',
#   'Wikipedia:WikiProject Richard Wagner',
#   'Composers',
#   'Music'],
#  ['Philosophy and religion',
#   'Religion',
#   'Christianity',
#   'Wikipedia:WikiProject Christian music',
#   'Popular music',
#   'Genres',
#   'Music',
#   'Popular musicians',
#   'Wikipedia:WikiProject Musicians',
#   'Biography',
#   'Wikipedia:WikiProject Persondata',
#   'Maintenance',
#   'Wikipedia assistance and tasks',
#   'root',
#   'Culture and the arts'],
#  ['History and society',
#   'Holidays and festivals',
#   'Wikipedia:WikiProject Holidays',
#   'Holidays',
#   'Religion',
#   'Christianity',
#   'Wikipedia:WikiProject Christian music',
#   'Popular music',
#   'Genres',
#   'Music',
#   'Popular musicians',
#   'Wikipedia:WikiProject Musicians',
#   'Biography',
#   'Wikipedia:WikiProject Persondata',
#   'Maintenance',
#   'Wikipedia assistance and tasks',
#   'root'],
#  ['Wikipedia:WikiProject Festivals',
#   'Holidays and festivals',
#   'Wikipedia:WikiProject Holidays',
#   'Holidays'],
#  ['History and society',
#   'Business and economics',
#   'Wikipedia:Jewish Labour Bund Task Force',
#   'Judaism',
#   'Religion',
#   'Christianity',
#   'Wikipedia:WikiProject Christian music',
#   'Popular music',
#   'Genres',
#   'Music',
#   'Popular musicians',
#   'Wikipedia:WikiProject Musicians',
#   'Biography',
#   'Wikipedia:WikiProject Persondata',
#   'Maintenance',
#   'Wikipedia assistance and tasks',
#   'root'],
#  ['Economics',
#   'Wikipedia:WikiProject Business',
#   'Business and economics',
#   'Wikipedia:Jewish Labour Bund Task Force',
#   'Judaism',
#   'Religion',
#   'Christianity',
#   'Wikipedia:WikiProject Christian music',
#   'Popular music',
#   'Genres',
#   'Music',
#   'Popular musicians',
#   'Wikipedia:WikiProject Musicians',
#   'Biography',
#   'Wikipedia:WikiProject Persondata',
#   'Maintenance',
#   'Wikipedia assistance and tasks',
#   'root',
#   'Culture and the arts',
#   'Sports',
#   'Wikipedia:WikiProject Caves',
#   'Landforms',
#   'Mountains',
#   'Wikipedia:WikiProject New Hampshire Mountains',
#   'Michigan–New York',
#   'United States',
#   'Wikipedia:WikiProject FBI',
#   'Law enforcement',
#   'Law',
#   'Politics and government',
#   'International',
#   'Wikipedia:WikiProject Sanitation',
#   'Medicine',
#   'Science, technology, and engineering'],
#  ['Economics',
#   'Wikipedia:WikiProject Investment',
#   'Business and economics',
#   'Wikipedia:Jewish Labour Bund Task Force',
#   'Judaism',
#   'Religion',
#   'Christianity',
#   'Wikipedia:WikiProject Christian music',
#   'Popular music',
#   'Genres',
#   'Music',
#   'Popular musicians',
#   'Wikipedia:WikiProject Musicians',
#   'Biography',
#   'Wikipedia:WikiProject Persondata',
#   'Maintenance',
#   'Wikipedia assistance and tasks',
#   'root',
#   'Culture and the arts',
#   'Sports',
#   'Wikipedia:WikiProject Caves',
#   'Landforms',
#   'Mountains',
#   'Wikipedia:WikiProject New Hampshire Mountains',
#   'Michigan–New York',
#   'United States',
#   'Wikipedia:WikiProject FBI',
#   'Law enforcement',
#   'Law',
#   'Politics and government',
#   'International',
#   'Wikipedia:WikiProject Sanitation',
#   'Medicine',
#   'Science, technology, and engineering'],
#  ['Economics',
#   'Wikipedia:WikiProject Economics',
#   'Business and economics',
#   'Wikipedia:Jewish Labour Bund Task Force',
#   'Judaism',
#   'Religion',
#   'Christianity',
#   'Wikipedia:WikiProject Christian music',
#   'Popular music',
#   'Genres',
#   'Music',
#   'Popular musicians',
#   'Wikipedia:WikiProject Musicians',
#   'Biography',
#   'Wikipedia:WikiProject Persondata',
#   'Maintenance',
#   'Wikipedia assistance and tasks',
#   'root',
#   'Culture and the arts',
#   'Sports',
#   'Wikipedia:WikiProject Caves',
#   'Landforms',
#   'Mountains',
#   'Wikipedia:WikiProject New Hampshire Mountains',
#   'Michigan–New York',
#   'United States',
#   'Wikipedia:WikiProject FBI',
#   'Law enforcement',
#   'Law',
#   'Politics and government',
#   'International',
#   'Wikipedia:WikiProject Sanitation',
#   'Medicine',
#   'Science, technology, and engineering'],
#  ['Geosciences',
#   'Wikipedia:WikiProject Mining',
#   'Business and economics',
#   'Wikipedia:Jewish Labour Bund Task Force',
#   'Judaism',
#   'Religion',
#   'Christianity',
#   'Wikipedia:WikiProject Christian music',
#   'Popular music',
#   'Genres',
#   'Music',
#   'Popular musicians',
#   'Wikipedia:WikiProject Musicians',
#   'Biography',
#   'Wikipedia:WikiProject Persondata',
#   'Maintenance',
#   'Wikipedia assistance and tasks',
#   'root',
#   'Culture and the arts',
#   'Sports',
#   'Wikipedia:WikiProject Caves',
#   'Landforms',
#   'Mountains',
#   'Wikipedia:WikiProject New Hampshire Mountains',
#   'Michigan–New York',
#   'United States',
#   'Wikipedia:WikiProject FBI',
#   'Law enforcement',
#   'Law',
#   'Politics and government',
#   'International',
#   'Wikipedia:WikiProject Sanitation',
#   'Medicine',
#   'Science, technology, and engineering'],
#  ['India',
#   'Wikipedia:WikiProject Indian music',
#   'National and regional',
#   'Music',
#   'Popular musicians',
#   'Wikipedia:WikiProject Musicians',
#   'Biography',
#   'Wikipedia:WikiProject Persondata',
#   'Maintenance',
#   'Wikipedia assistance and tasks',
#   'root',
#   'Culture and the arts',
#   'Sports',
#   'Wikipedia:WikiProject Caves',
#   'Landforms',
#   'Mountains',
#   'Wikipedia:WikiProject New Hampshire Mountains',
#   'Michigan–New York',
#   'United States',
#   'Wikipedia:WikiProject FBI',
#   'Law enforcement',
#   'Law',
#   'Politics and government',
#   'International',
#   'Wikipedia:WikiProject Sanitation',
#   'Medicine',
#   'Science, technology, and engineering',
#   'Science',
#   'Wikipedia:WikiProject Forestry',
#   'General topics',
#   'Wikipedia:WikiProject Former countries',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt',
#   'Northern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Files',
#   'Wikipedia:WikiProject OpenStreetMap',
#   'Maintenance',
#   'Wikipedia assistance and tasks'],
#  ['Geography',
#   'Wikipedia:WikiProject Geographical coordinates',
#   'Maintenance',
#   'Wikipedia assistance and tasks',
#   'root',
#   'Culture and the arts',
#   'Sports',
#   'Wikipedia:WikiProject Caves',
#   'Landforms'],
#  ['Geography',
#   'Maps',
#   'Wikipedia:WikiProject Maps',
#   'Files',
#   'Wikipedia assistance and tasks',
#   'root',
#   'Culture and the arts',
#   'Sports',
#   'Wikipedia:WikiProject Caves',
#   'Landforms'],
#  ['Visual arts',
#   'Photography',
#   'Wikipedia:WikiProject Photography',
#   'Files',
#   'Wikipedia assistance and tasks',
#   'root',
#   'Culture and the arts'],
#  ['Wikipedia:WikiProject Alternative medicine',
#   'Philosophy',
#   'Philosophy and religion',
#   'Culture and the arts',
#   'Sports',
#   'Wikipedia:WikiProject Caves',
#   'Landforms',
#   'Mountains',
#   'Wikipedia:WikiProject New Hampshire Mountains',
#   'Michigan–New York',
#   'United States',
#   'Wikipedia:WikiProject FBI',
#   'Law enforcement',
#   'Law',
#   'Politics and government',
#   'International',
#   'Wikipedia:WikiProject Sanitation',
#   'Medicine'],
#  ['Space',
#   'Wikipedia:WikiProject Cosmology',
#   'Philosophy',
#   'Philosophy and religion',
#   'Culture and the arts',
#   'Sports',
#   'Wikipedia:WikiProject Caves',
#   'Landforms',
#   'Mountains',
#   'Wikipedia:WikiProject New Hampshire Mountains',
#   'Michigan–New York',
#   'United States',
#   'Wikipedia:WikiProject FBI',
#   'Law enforcement',
#   'Law',
#   'Politics and government',
#   'International',
#   'Wikipedia:WikiProject Sanitation',
#   'Medicine',
#   'Science, technology, and engineering'],
#  ['Board and table games',
#   'Wikipedia:WikiProject Board and table games',
#   'Games',
#   'Games and toys'],
#  ['History and society',
#   'Transportation',
#   'Wikipedia:WikiProject Cycling',
#   'Sports',
#   'Wikipedia:WikiProject Caves',
#   'Landforms',
#   'Mountains',
#   'Wikipedia:WikiProject New Hampshire Mountains',
#   'Michigan–New York',
#   'United States',
#   'Wikipedia:WikiProject FBI',
#   'Law enforcement',
#   'Law',
#   'Politics and government'],
#  ['Wikipedia:WikiProject Running',
#   'Transportation',
#   'Wikipedia:WikiProject Cycling',
#   'Sports'],
#  ['Technology',
#   'Wikipedia:WikiProject Alternative fuels',
#   'Transportation',
#   'Wikipedia:WikiProject Cycling',
#   'Sports',
#   'Wikipedia:WikiProject Caves',
#   'Landforms',
#   'Mountains',
#   'Wikipedia:WikiProject New Hampshire Mountains',
#   'Michigan–New York',
#   'United States',
#   'Wikipedia:WikiProject FBI',
#   'Law enforcement',
#   'Law',
#   'Politics and government',
#   'International',
#   'Wikipedia:WikiProject Sanitation',
#   'Medicine',
#   'Science, technology, and engineering'],
#  ['Trains',
#   'Wikipedia:WikiProject New York City Public Transportation',
#   'Transportation'],
#  ['Wikipedia:WikiProject Ports', 'Maritime', 'Transportation'],
#  ['Wikipedia:WikiProject Maritime Trades', 'Maritime', 'Transportation'],
#  ['Wikipedia:WikiProject Stations', 'Trains', 'Transportation'],
#  ['Technology',
#   'Aviation',
#   'Transportation',
#   'Wikipedia:WikiProject Cycling',
#   'Sports',
#   'Wikipedia:WikiProject Caves',
#   'Landforms',
#   'Mountains',
#   'Wikipedia:WikiProject New Hampshire Mountains',
#   'Michigan–New York',
#   'United States',
#   'Wikipedia:WikiProject FBI',
#   'Law enforcement',
#   'Law',
#   'Politics and government',
#   'International',
#   'Wikipedia:WikiProject Sanitation',
#   'Medicine',
#   'Science, technology, and engineering'],
#  ['Geography',
#   'Wikipedia:WikiProject Ports',
#   'Transportation',
#   'Wikipedia:WikiProject Cycling',
#   'Sports',
#   'Wikipedia:WikiProject Caves',
#   'Landforms'],
#  ['Wikipedia:WikiProject Boxing', 'Martial arts', 'Sports'],
#  ['Countries',
#   'Geography',
#   'Landforms',
#   'Mountains',
#   'Wikipedia:WikiProject New Hampshire Mountains',
#   'Michigan–New York',
#   'United States',
#   'Wikipedia:WikiProject FBI',
#   'Law enforcement',
#   'Law',
#   'Politics and government',
#   'International',
#   'Wikipedia:WikiProject Sanitation',
#   'Medicine',
#   'Science, technology, and engineering',
#   'Science',
#   'Wikipedia:WikiProject Forestry',
#   'General topics',
#   'Wikipedia:WikiProject Former countries',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt',
#   'Northern Africa',
#   'Africa'],
#  ['Wikipedia:WikiProject UK Waterways',
#   'Bodies of water',
#   'Geography',
#   'Landforms',
#   'Mountains',
#   'Wikipedia:WikiProject New Hampshire Mountains',
#   'Michigan–New York',
#   'United States',
#   'Wikipedia:WikiProject FBI',
#   'Law enforcement',
#   'Law',
#   'Politics and government',
#   'International',
#   'Wikipedia:WikiProject Sanitation',
#   'Medicine',
#   'Science, technology, and engineering',
#   'Science',
#   'Wikipedia:WikiProject Forestry',
#   'General topics',
#   'Wikipedia:WikiProject Former countries',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt',
#   'Northern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth',
#   'United Kingdom'],
#  ['North America',
#   'Cities of the United States',
#   'Cities',
#   'Geography',
#   'Landforms',
#   'Mountains',
#   'Wikipedia:WikiProject New Hampshire Mountains',
#   'Michigan–New York',
#   'United States'],
#  ['Caribbean',
#   'Cities of the United States',
#   'Cities',
#   'Geography',
#   'Landforms',
#   'Mountains',
#   'Wikipedia:WikiProject New Hampshire Mountains',
#   'Michigan–New York',
#   'United States',
#   'Wikipedia:WikiProject FBI',
#   'Law enforcement',
#   'Law',
#   'Politics and government',
#   'International',
#   'Wikipedia:WikiProject Sanitation',
#   'Medicine',
#   'Science, technology, and engineering',
#   'Science',
#   'Wikipedia:WikiProject Forestry',
#   'General topics',
#   'Wikipedia:WikiProject Former countries',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt',
#   'Northern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Americas', 'Central America', 'Cities of the United States'],
#  ['Wikipedia:WikiProject Mesoamerica',
#   'Central America',
#   'Cities of the United States',
#   'Cities',
#   'Geography',
#   'Landforms',
#   'Mountains',
#   'Wikipedia:WikiProject New Hampshire Mountains',
#   'Michigan–New York',
#   'United States',
#   'Wikipedia:WikiProject FBI',
#   'Law enforcement',
#   'Law',
#   'Politics and government',
#   'International',
#   'Wikipedia:WikiProject Sanitation',
#   'Medicine',
#   'Science, technology, and engineering',
#   'Science',
#   'Wikipedia:WikiProject Forestry',
#   'General topics',
#   'Wikipedia:WikiProject Former countries',
#   'History'],
#  ['Americas', 'South America', 'Cities of the United States'],
#  ['Caribbean',
#   'Wikipedia:WikiProject Guyana',
#   'South America',
#   'Cities of the United States'],
#  ['North America', 'Americas', 'Cities of the United States'],
#  ['Caribbean', 'Americas', 'Cities of the United States'],
#  ['Countries',
#   'Americas',
#   'Cities of the United States',
#   'Cities',
#   'Geography'],
#  ['Australia',
#   'Wikipedia:WikiProject Demographics of Australia',
#   'Geography',
#   'Landforms',
#   'Mountains',
#   'Wikipedia:WikiProject New Hampshire Mountains',
#   'Michigan–New York',
#   'United States',
#   'Wikipedia:WikiProject FBI',
#   'Law enforcement',
#   'Law',
#   'Politics and government',
#   'International',
#   'Wikipedia:WikiProject Sanitation',
#   'Medicine',
#   'Science, technology, and engineering',
#   'Science',
#   'Wikipedia:WikiProject Forestry',
#   'General topics',
#   'Wikipedia:WikiProject Former countries',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt',
#   'Northern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Hawaii–Massachusetts',
#   'Wikipedia:WikiProject Kansas City',
#   'Michigan–New York',
#   'United States'],
#  ['Canada',
#   'North America',
#   'United States',
#   'Wikipedia:WikiProject FBI',
#   'Law enforcement',
#   'Law',
#   'Politics and government',
#   'International',
#   'Wikipedia:WikiProject Sanitation',
#   'Medicine',
#   'Science, technology, and engineering',
#   'Science',
#   'Wikipedia:WikiProject Forestry',
#   'General topics',
#   'Wikipedia:WikiProject Former countries',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt',
#   'Northern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Telecommunications', 'Wikipedia:WikiProject Bell System', 'Technology'],
#  ['Wikipedia:WikiProject Environment',
#   'Biology',
#   'Science, technology, and engineering',
#   'Science',
#   'Wikipedia:WikiProject Forestry',
#   'General topics'],
#  ['Wikipedia:WikiProject Assyria',
#   'Ethnic groups',
#   'History and society',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt'],
#  ['Schools',
#   'Education',
#   'History and society',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt',
#   'Northern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth',
#   'United Kingdom',
#   'England',
#   'South East England',
#   'Wikipedia:WikiProject University of Oxford',
#   'Colleges and universities'],
#  ['Cyprus',
#   'Southwest Asia',
#   'Israel',
#   'Wikipedia:WikiProject Israel Palestine Collaboration',
#   'Ethnic conflict resolution projects',
#   'History and society',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt',
#   'Northern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Wikipedia:WikiProject Assyria',
#   'Southwest Asia',
#   'Israel',
#   'Wikipedia:WikiProject Israel Palestine Collaboration',
#   'Ethnic conflict resolution projects',
#   'History and society',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt'],
#  ['Countries',
#   'Unrecognized countries',
#   'Wikipedia:WikiProject Abkhazia',
#   'Caucasia',
#   'Southwest Asia',
#   'Israel',
#   'Wikipedia:WikiProject Israel Palestine Collaboration',
#   'Ethnic conflict resolution projects',
#   'History and society',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt',
#   'Northern Africa',
#   'Africa'],
#  ['Countries',
#   'Asia',
#   'Southwest Asia',
#   'Israel',
#   'Wikipedia:WikiProject Israel Palestine Collaboration',
#   'Ethnic conflict resolution projects',
#   'History and society',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt',
#   'Northern Africa',
#   'Africa'],
#  ['Bangladesh',
#   'South Asia',
#   'Asia',
#   'Southwest Asia',
#   'Israel',
#   'Wikipedia:WikiProject Israel Palestine Collaboration',
#   'Ethnic conflict resolution projects',
#   'History and society',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt',
#   'Northern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Maldives',
#   'South Asia',
#   'Asia',
#   'Southwest Asia',
#   'Israel',
#   'Wikipedia:WikiProject Israel Palestine Collaboration',
#   'Ethnic conflict resolution projects',
#   'History and society',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt',
#   'Northern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Pakistan',
#   'South Asia',
#   'Asia',
#   'Southwest Asia',
#   'Israel',
#   'Wikipedia:WikiProject Israel Palestine Collaboration',
#   'Ethnic conflict resolution projects',
#   'History and society',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt',
#   'Northern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['India',
#   'South Asia',
#   'Asia',
#   'Southwest Asia',
#   'Israel',
#   'Wikipedia:WikiProject Israel Palestine Collaboration',
#   'Ethnic conflict resolution projects',
#   'History and society',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt',
#   'Northern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Northern Europe',
#   'Europe',
#   'Eastern Europe',
#   'Russia',
#   'North Asia',
#   'Asia',
#   'Southwest Asia',
#   'Israel',
#   'Wikipedia:WikiProject Israel Palestine Collaboration',
#   'Ethnic conflict resolution projects',
#   'History and society',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt',
#   'Northern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth',
#   'United Kingdom'],
#  ['Countries', 'Europe', 'Eastern Europe', 'Russia', 'North Asia', 'Asia'],
#  ['Malta',
#   'Southern Europe',
#   'Europe',
#   'Eastern Europe',
#   'Russia',
#   'North Asia',
#   'Asia',
#   'Southwest Asia',
#   'Israel',
#   'Wikipedia:WikiProject Israel Palestine Collaboration',
#   'Ethnic conflict resolution projects',
#   'History and society',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt',
#   'Northern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Germany', 'Wikipedia:WikiProject Frisia', 'Netherlands', 'Western Europe'],
#  ['Wikipedia:WikiProject Hanseatic League',
#   'Germany',
#   'Western Europe',
#   'Europe',
#   'Eastern Europe',
#   'Russia',
#   'North Asia',
#   'Asia',
#   'Southwest Asia',
#   'Israel',
#   'Wikipedia:WikiProject Israel Palestine Collaboration',
#   'Ethnic conflict resolution projects',
#   'History and society',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt',
#   'Northern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth',
#   'United Kingdom'],
#  ['Brunei',
#   'Southeast Asia',
#   'Asia',
#   'Southwest Asia',
#   'Israel',
#   'Wikipedia:WikiProject Israel Palestine Collaboration',
#   'Ethnic conflict resolution projects',
#   'History and society',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt',
#   'Northern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Malaysia',
#   'Southeast Asia',
#   'Asia',
#   'Southwest Asia',
#   'Israel',
#   'Wikipedia:WikiProject Israel Palestine Collaboration',
#   'Ethnic conflict resolution projects',
#   'History and society',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt',
#   'Northern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Singapore',
#   'Southeast Asia',
#   'Asia',
#   'Southwest Asia',
#   'Israel',
#   'Wikipedia:WikiProject Israel Palestine Collaboration',
#   'Ethnic conflict resolution projects',
#   'History and society',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt',
#   'Northern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Australia',
#   'Oceania',
#   'Melanesia',
#   'Wikipedia:WikiProject East Timor',
#   'Southeast Asia',
#   'Asia',
#   'Southwest Asia',
#   'Israel',
#   'Wikipedia:WikiProject Israel Palestine Collaboration',
#   'Ethnic conflict resolution projects',
#   'History and society',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt',
#   'Northern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Countries',
#   'Oceania',
#   'Melanesia',
#   'Wikipedia:WikiProject East Timor',
#   'Southeast Asia',
#   'Asia'],
#  ['New Zealand',
#   'Oceania',
#   'Melanesia',
#   'Wikipedia:WikiProject East Timor',
#   'Southeast Asia',
#   'Asia',
#   'Southwest Asia',
#   'Israel',
#   'Wikipedia:WikiProject Israel Palestine Collaboration',
#   'Ethnic conflict resolution projects',
#   'History and society',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt',
#   'Northern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Kiribati',
#   'Micronesia',
#   'Oceania',
#   'Melanesia',
#   'Wikipedia:WikiProject East Timor',
#   'Southeast Asia',
#   'Asia',
#   'Southwest Asia',
#   'Israel',
#   'Wikipedia:WikiProject Israel Palestine Collaboration',
#   'Ethnic conflict resolution projects',
#   'History and society',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt',
#   'Northern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Nauru',
#   'Micronesia',
#   'Oceania',
#   'Melanesia',
#   'Wikipedia:WikiProject East Timor',
#   'Southeast Asia',
#   'Asia',
#   'Southwest Asia',
#   'Israel',
#   'Wikipedia:WikiProject Israel Palestine Collaboration',
#   'Ethnic conflict resolution projects',
#   'History and society',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt',
#   'Northern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Tuvalu',
#   'Polynesia',
#   'Oceania',
#   'Melanesia',
#   'Wikipedia:WikiProject East Timor',
#   'Southeast Asia',
#   'Asia',
#   'Southwest Asia',
#   'Israel',
#   'Wikipedia:WikiProject Israel Palestine Collaboration',
#   'Ethnic conflict resolution projects',
#   'History and society',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt',
#   'Northern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Tonga',
#   'Polynesia',
#   'Oceania',
#   'Melanesia',
#   'Wikipedia:WikiProject East Timor',
#   'Southeast Asia',
#   'Asia',
#   'Southwest Asia',
#   'Israel',
#   'Wikipedia:WikiProject Israel Palestine Collaboration',
#   'Ethnic conflict resolution projects',
#   'History and society',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt',
#   'Northern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Samoa',
#   'Polynesia',
#   'Oceania',
#   'Melanesia',
#   'Wikipedia:WikiProject East Timor',
#   'Southeast Asia',
#   'Asia',
#   'Southwest Asia',
#   'Israel',
#   'Wikipedia:WikiProject Israel Palestine Collaboration',
#   'Ethnic conflict resolution projects',
#   'History and society',
#   'History',
#   'Wikipedia:WikiProject Ancient Near East',
#   'Egypt',
#   'Northern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Namibia',
#   'Southern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Botswana',
#   'Southern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Lesotho',
#   'Southern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Cameroon',
#   'Central Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Seychelles',
#   'Eastern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Kenya',
#   'Eastern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Malawi',
#   'Eastern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Mauritius',
#   'Eastern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Uganda',
#   'Eastern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Mozambique',
#   'Eastern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Australia', 'Countries', 'Wikipedia:WikiProject Commonwealth']]

# %%
nx.shortest_path_length(G,'Wikipedia:WikiProject India','Wikipedia:WikiProject Bangladesh')
# Out:
# 4

# %%
nx.shortest_path_length(G,'Wikipedia:WikiProject India','Wikipedia:WikiProject Brazil')
# Out:
# 6
