# %% [markdown]
# * Use the wikiproject tree generated from https://github.com/wiki-ai/drafttopic/tree/master/drafttopic/utilities

# %%
import json, networkx as nx
import pickle

# %%
with open('wp_2017-11-05.json') as f: tree = json.load(f)

# %%
def getLinks(dictCat):
    return dictCat.get('topics',{})

def normalizeName(name): #normalize names to match with SQL output, see example here: https://quarry.wmflabs.org/query/23214
    if name.startswith("Wikipedia:"):
        name =name[10:]
    if not name.startswith("WikiProject"):
        name = "WikiProject_"+name
    name = name+"_articles"
    name = name.replace(' ','_')
    return name

# %%
root= {'topics':tree,'name':'root'}

visited = []
G = nx.Graph()
stack = [root]
while stack:
    #print(stack)
    current = stack.pop()
    childs = getLinks(current)
    #print(childs)
    visited.append(current)
    #print(current)
    for topic,topicDict in childs.items():
            if topicDict['name'] != current['name']: #avoid selfloops
                G.add_edge(topicDict['name'],current['name'])
                if c not in visited+stack:
                    stack.append(topicDict)

# %%
nx.algorithms.is_tree(G)
# Out:
# False

# %%
len(nx.cycle_basis(G))
# Out:
# 76

# %%
nx.cycle_basis(G)
# Out:
# [['Countries', 'Asia', 'North Asia', 'Russia', 'Eastern Europe', 'Europe'],
#  ['Bangladesh', 'Wikipedia:WikiProject Commonwealth', 'India', 'South Asia'],
#  ['Maldives', 'Wikipedia:WikiProject Commonwealth', 'India', 'South Asia'],
#  ['Countries',
#   'Wikipedia:WikiProject Commonwealth',
#   'India',
#   'South Asia',
#   'Asia'],
#  ['Pakistan', 'Wikipedia:WikiProject Commonwealth', 'India', 'South Asia'],
#  ['Malta',
#   'Wikipedia:WikiProject Commonwealth',
#   'India',
#   'South Asia',
#   'Asia',
#   'North Asia',
#   'Russia',
#   'Eastern Europe',
#   'Europe',
#   'Southern Europe'],
#  ['Nigeria', 'Western Africa', 'Gambia', 'Wikipedia:WikiProject Commonwealth'],
#  ['Sierra Leone',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Ghana', 'Western Africa', 'Gambia', 'Wikipedia:WikiProject Commonwealth'],
#  ['Countries',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Southwest Asia',
#   'Wikipedia:WikiProject Assyria',
#   'Egypt',
#   'Northern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth',
#   'India',
#   'South Asia',
#   'Asia'],
#  ['Namibia',
#   'Southern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Botswana',
#   'Southern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Lesotho',
#   'Southern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Cameroon',
#   'Central Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Seychelles',
#   'Eastern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Kenya',
#   'Eastern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Malawi',
#   'Eastern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Mauritius',
#   'Eastern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Uganda',
#   'Eastern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Mozambique',
#   'Eastern Africa',
#   'Africa',
#   'Western Africa',
#   'Gambia',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Southeast Asia',
#   'Malaysia',
#   'Wikipedia:WikiProject Commonwealth',
#   'India',
#   'South Asia',
#   'Asia'],
#  ['Tonga', 'Polynesia', 'Tuvalu', 'Wikipedia:WikiProject Commonwealth'],
#  ['Samoa', 'Polynesia', 'Tuvalu', 'Wikipedia:WikiProject Commonwealth'],
#  ['Australia',
#   'Oceania',
#   'Polynesia',
#   'Tuvalu',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Countries',
#   'Oceania',
#   'Polynesia',
#   'Tuvalu',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['New Zealand',
#   'Oceania',
#   'Polynesia',
#   'Tuvalu',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Kiribati',
#   'Micronesia',
#   'Oceania',
#   'Polynesia',
#   'Tuvalu',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Nauru',
#   'Micronesia',
#   'Oceania',
#   'Polynesia',
#   'Tuvalu',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Southeast Asia',
#   'Wikipedia:WikiProject East Timor',
#   'Melanesia',
#   'Oceania',
#   'Polynesia',
#   'Tuvalu',
#   'Wikipedia:WikiProject Commonwealth',
#   'India',
#   'South Asia',
#   'Asia'],
#  ['Southwest Asia',
#   'Cyprus',
#   'Wikipedia:WikiProject Commonwealth',
#   'India',
#   'South Asia',
#   'Asia'],
#  ['Southeast Asia',
#   'Brunei',
#   'Wikipedia:WikiProject Commonwealth',
#   'India',
#   'South Asia',
#   'Asia'],
#  ['Southeast Asia',
#   'Singapore',
#   'Wikipedia:WikiProject Commonwealth',
#   'India',
#   'South Asia',
#   'Asia'],
#  ['Americas', 'Cities of the United States', 'North America'],
#  ['Caribbean',
#   'Cities of the United States',
#   'North America',
#   'Canada',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Countries',
#   'Geography',
#   'Cities',
#   'Cities of the United States',
#   'North America',
#   'Canada',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['United States',
#   'Michigan–New York',
#   'Wikipedia:WikiProject New Hampshire Mountains',
#   'Mountains',
#   'Landforms',
#   'Geography',
#   'Cities',
#   'Cities of the United States',
#   'North America'],
#  ['United States',
#   'Hawaii–Massachusetts',
#   'Wikipedia:WikiProject Kansas City',
#   'Michigan–New York'],
#  ['Maintenance',
#   'Wikipedia:WikiProject Council',
#   'WikiProjects',
#   'Wikipedia assistance and tasks'],
#  ['Geographical',
#   'root',
#   'Wikipedia assistance and tasks',
#   'Files',
#   'Wikipedia:WikiProject Maps',
#   'Maps',
#   'Geography'],
#  ['History and society',
#   'Politics and government',
#   'International',
#   'Wikipedia:WikiProject Sanitation',
#   'Medicine',
#   'Science, technology, and engineering',
#   'Science, technology and engineering',
#   'root'],
#  ['Biology',
#   'Tree of Life',
#   'Plants',
#   'Wikipedia:WikiProject Cannabis',
#   'Politics and government',
#   'International',
#   'Wikipedia:WikiProject Sanitation',
#   'Medicine',
#   'Science, technology, and engineering'],
#  ['Marine life',
#   'Wikipedia:WikiProject Gastropods',
#   'Animals',
#   'Tree of Life'],
#  ['Marine life', 'Wikipedia:WikiProject Bivalves', 'Animals', 'Tree of Life'],
#  ['United States',
#   'Wikipedia:WikiProject FBI',
#   'Law enforcement',
#   'Law',
#   'Politics and government',
#   'International',
#   'Wikipedia:WikiProject Sanitation',
#   'Medicine',
#   'Science, technology, and engineering',
#   'Science, technology and engineering',
#   'root',
#   'Wikipedia assistance and tasks',
#   'Files',
#   'Wikipedia:WikiProject Maps',
#   'Maps',
#   'Geography',
#   'Cities',
#   'Cities of the United States',
#   'North America'],
#  ['Wikipedia:WikiProject Economics',
#   'Business and economics',
#   'Wikipedia:WikiProject Investment',
#   'Economics'],
#  ['Wikipedia:WikiProject Business',
#   'Business and economics',
#   'Wikipedia:WikiProject Investment',
#   'Economics'],
#  ['History and society',
#   'Business and economics',
#   'Wikipedia:WikiProject Investment',
#   'Economics',
#   'Science, technology, and engineering',
#   'Science, technology and engineering',
#   'root'],
#  ['Geosciences',
#   'Wikipedia:WikiProject Mining',
#   'Business and economics',
#   'Wikipedia:WikiProject Investment',
#   'Economics',
#   'Science, technology, and engineering'],
#  ['Telecommunications', 'Wikipedia:WikiProject Bell System', 'Technology'],
#  ['Wikipedia:WikiProject Ports',
#   'Transportation',
#   'Aviation',
#   'Technology',
#   'Science, technology, and engineering',
#   'Science, technology and engineering',
#   'root',
#   'Wikipedia assistance and tasks',
#   'Files',
#   'Wikipedia:WikiProject Maps',
#   'Maps',
#   'Geography'],
#  ['History and society',
#   'Transportation',
#   'Aviation',
#   'Technology',
#   'Science, technology, and engineering',
#   'Science, technology and engineering',
#   'root'],
#  ['Wikipedia:WikiProject Alternative fuels',
#   'Transportation',
#   'Aviation',
#   'Technology'],
#  ['Trains',
#   'Wikipedia:WikiProject New York City Public Transportation',
#   'Transportation'],
#  ['Wikipedia:WikiProject Ports', 'Maritime', 'Transportation'],
#  ['Wikipedia:WikiProject Maritime Trades', 'Maritime', 'Transportation'],
#  ['Wikipedia:WikiProject Stations', 'Trains', 'Transportation'],
#  ['United Kingdom',
#   'England',
#   'South East England',
#   'Wikipedia:WikiProject University of Oxford',
#   'Colleges and universities',
#   'Schools',
#   'Education',
#   'History and society',
#   'root',
#   'Wikipedia assistance and tasks',
#   'Files',
#   'Wikipedia:WikiProject Maps',
#   'Maps',
#   'Geography',
#   'Cities',
#   'Cities of the United States',
#   'North America',
#   'Canada',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['East Midlands',
#   'Wikipedia:WikiProject Lincolnshire',
#   'Yorkshire and the Humber',
#   'England'],
#  ['Cambridge', 'Wikipedia:WikiProject East Anglia', 'East of England'],
#  ['Maintenance',
#   'Wikipedia:Help Project',
#   'Contents systems',
#   'Wikipedia assistance and tasks'],
#  ['Maintenance',
#   'Wikipedia:WikiProject Portals',
#   'Contents systems',
#   'Wikipedia assistance and tasks'],
#  ['Wikipedia:WikiProject Geographical coordinates',
#   'Maintenance',
#   'Wikipedia assistance and tasks',
#   'Files',
#   'Wikipedia:WikiProject Maps',
#   'Maps',
#   'Geography'],
#  ['Wikipedia:WikiProject OpenStreetMap',
#   'Maintenance',
#   'Wikipedia assistance and tasks',
#   'Files'],
#  ['United Kingdom',
#   'Wikipedia:WikiProject UK Waterways',
#   'Bodies of water',
#   'Geography',
#   'Cities',
#   'Cities of the United States',
#   'North America',
#   'Canada',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Australia',
#   'Wikipedia:WikiProject Demographics of Australia',
#   'Geography',
#   'Cities',
#   'Cities of the United States',
#   'North America',
#   'Canada',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Americas', 'Central America', 'Cities of the United States'],
#  ['Americas', 'South America', 'Cities of the United States'],
#  ['Caribbean',
#   'Wikipedia:WikiProject Guyana',
#   'South America',
#   'Cities of the United States'],
#  ['Caribbean',
#   'Americas',
#   'North America',
#   'Canada',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Countries',
#   'Americas',
#   'North America',
#   'Canada',
#   'Wikipedia:WikiProject Commonwealth'],
#  ['Countries', 'Australia', 'Wikipedia:WikiProject Commonwealth'],
#  ['Northern Europe',
#   'United Kingdom',
#   'Wikipedia:WikiProject Commonwealth',
#   'India',
#   'South Asia',
#   'Asia',
#   'North Asia',
#   'Russia',
#   'Eastern Europe',
#   'Europe'],
#  ['Western Europe',
#   'Germany',
#   'Wikipedia:WikiProject Hanseatic League',
#   'United Kingdom',
#   'Wikipedia:WikiProject Commonwealth',
#   'India',
#   'South Asia',
#   'Asia',
#   'North Asia',
#   'Russia',
#   'Eastern Europe',
#   'Europe'],
#  ['Western Europe', 'Netherlands', 'Wikipedia:WikiProject Frisia', 'Germany'],
#  ['Countries',
#   'Unrecognized countries',
#   'Wikipedia:WikiProject Abkhazia',
#   'Caucasia',
#   'Southwest Asia',
#   'Asia']]
